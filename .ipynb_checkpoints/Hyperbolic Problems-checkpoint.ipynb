# %%
import sympy as sym
import scipy.sparse as sp
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, Markdown, Latex, clear_output
from time import sleep

# %%
def plot_sol_in_time(t,x,sol,wait=0.005):
    _min = sol.min()
    _max = sol.max()
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    step = len(t) // 200
    for i in range(0,len(t)-1,step):
        ax.cla()
        ax.title.set_text("Time: " + str(round(t[i],3)) + " s")      
        ax.plot(x, sol[i])
        ax.set_xlim(0, x.max())
        ax.set_ylim(_min, _max)
        display(fig)
        clear_output(wait = True)
        sleep(wait)

# %%
def plot_sol_in_3d(t,x,sol):
    X, Y = np.meshgrid(x, t)
    fig = plt.figure(figsize=(10, 8))
    ax = plt.axes(projection='3d')
    ax.plot_surface(X, Y, sol, rstride=1, cstride=1,cmap='jet', edgecolor='none')
    ax.set_xlabel('x')
    ax.set_ylabel('t')
    ax.set_zlabel('z');

# %% [markdown]
# # Advection problem

# %%
class ad_pb_fd_method:
    
    def __init__(self, alpha, u_0, g, a = 0, b = 1, T = 1):
        self.a = a
        self.b = b
        self.T = T
        self.alpha = alpha
        self.u_0 = u_0
        self.g = g
    
    def h(self):
        return (self.b - self.a)/self.N_x
        
    def tau(self):
        return self.T/self.N_t
    
    def courant_number(self):
        return abs(self.alpha) * self.tau() / self.h()
    
    def index_at_t(self, t):
        assert t >= 0 and t < self.T
        return int(t/self.tau())
    
    def index_at_x(self, x):
        assert x >= self.a and x < self.b 
        return int((x - self.a)/self.h())
    
    def x_array(self):
        return np.linspace(self.a,self.b,self.N_x)
    
    def t_array(self):
        return np.linspace(0,self.T,self.N_t)
    
    def compute_solution(self):
        pass

# %% [markdown]
# ## Upwind method

# %%
class upwind_method(ad_pb_fd_method):
    
    def __init__(self, alpha, u_0, g, a = 0, b = 1, T = 1):
        super().__init__(alpha, u_0, g, a, b, T)
        
    def compute_solution(self):
        
        eta = self.courant_number()
        if eta > 1:
            print("The method is unstable!")
            
        U = np.zeros((self.N_t, self.N_x))
        coeffs = [eta * np.ones(self.N_x-1), (1 - eta) * np.ones(self.N_x)]
        A = sp.diags(coeffs,[-1,0], format="csr")
        u_0_np = np.vectorize(self.u_0)
        g_np = np.vectorize(self.g)
        x = np.linspace(self.a,self.b,self.N_x)
        t = np.linspace(0,self.T,self.N_t)
        
        U[0,:] = u_0_np(x)
        bc = 0 if self.alpha > 0 else self.N_x - 1
        U[:,bc] = g_np(t)
        for i in range(1,self.N_t):
            U[i,:] = A.dot(U[i-1,:])
        
        return U

# %%
def u_0(x):
    return 10**4*(0.1 - x)**2*(0.2-x)**2 if 0.1 < x and x < 0.2 else 0.0
g = lambda x : 0

# %%
um = upwind_method(0.7,u_0,g)

um.N_x = 285
um.N_t = 200

x = um.x_array()
t = um.t_array()

U_up = um.compute_solution()

print(um.courant_number())
# Out:
# 0.9974999999999998

# %%
plot_sol_in_time(t,x,U_up)

# %%
plot_sol_in_3d(t,x,U_up)

# %%
um.N_t = 200
um.N_x = 293

x = um.x_array()
t = um.t_array()

U = um.compute_solution()

print(um.courant_number())
# Out:
# The method is unstable!
# 1.0254999999999999

# %%
plot_sol_in_time(t,x,U)

# %%
plot_sol_in_3d(t,x,U)

# %% [markdown]
# ## Lax-Wendroff method

# %%
class lw_method(ad_pb_fd_method):
    
    def __init__(self, alpha, u_0, g, a = 0, b = 1, T = 1):
        super().__init__(alpha, u_0, g, a, b, T)
        
    def compute_solution(self):
        
        eta = self.courant_number()
        if eta > 1:
            print("The method is unstable!")
            
        U = np.zeros((self.N_t,self.N_x))
        coeffs = [.5 * eta * (1 + eta) * np.ones(self.N_x-1),(1 - eta**2) * np.ones(self.N_x),-0.5 * eta * (1 - eta) * np.ones(self.N_x-1)]
        A = sp.diags(coeffs,[-1,0,1], format="csr")
        u_0 = np.vectorize(self.u_0)
        g = np.vectorize(self.g)
        x = np.linspace(self.a,self.b,self.N_x)
        t = np.linspace(0,self.T,self.N_t)
        
        U[0,:] = u_0(x)
        bc = 0 if self.alpha > 0 else self.N_x - 1
        U[:,bc] = g(t)
        for i in range(1,self.N_t):
            U[i,:] = A.dot(U[i-1,:])
        
        return U

# %%
lw = lw_method(0.7,u_0,g)

lw.N_t = 200
lw.N_x = 250

U_lw = lw.compute_solution()

x = lw.x_array()
t = lw.t_array()

print(lw.courant_number())
# Out:
# 0.8749999999999999

# %%
plot_sol_in_time(t,x,U_lw)

# %%
plot_sol_in_3d(t,x,U_lw)

# %%
def compare_fd_at(fd_1,fd_2,timestamps):
    U_1 = fd_1.compute_solution()
    U_2 = fd_2.compute_solution()
    cols = 2
    rows = (len(timestamps) - 1) // cols + 1
    fig, axs = plt.subplots(rows, cols, figsize = (18,12))
    axs = axs.flat
    for k in range(len(axs)):
        if k < len(timestamps):
                i_1 = fd_1.index_at_t(timestamps[k])
                i_2 = fd_2.index_at_t(timestamps[k])
                axs[k].plot(fd_1.x_array(),U_1[i_1])
                axs[k].plot(fd_2.x_array(),U_2[i_2])
        else:
            fig.delaxes(axs[k])

# %%
um.N_x = 285
um.N_t = 200

compare_fd_at(um,lw,[0,0.1,0.5,0.9])
